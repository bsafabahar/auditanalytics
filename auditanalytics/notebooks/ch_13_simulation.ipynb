# %% [markdown]
# # Chapter 13: Simulated Transactions for Auditing Service Organizations
#
# This notebook demonstrates Python implementations of audit analytics techniques for Simulated Transactions for Auditing Service Organizations.
#
# ## Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import auditanalytics as aa

sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# ## Introduction
#
# Content for Chapter 13 will be added here.

# %%
# List available datasets
from auditanalytics.data import list_datasets
datasets = list_datasets()
print(f"Available datasets: {len(datasets)}")
print("
First 10 datasets:")
for ds in sorted(datasets)[:10]:
    print(f"  - {ds}")

# %% [markdown]
# ## Conclusion
#
# This notebook provides examples for Chapter 13.
